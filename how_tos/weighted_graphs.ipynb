# %% [markdown]
# ## Optimizing the parameters of weighted graphs
#
# In this How-To we optimize QAOA parameters for a graph with weighted edges. In particular we leverage the work of Sureshbabu *et al.*, Quantum **8**, 1231 (2024). In this work, the authors first derive the parameters for unweighted graphs $(\beta, \gamma)$ and then derive parameters for the weighted graphs by rescaling $\gamma$ following
# \begin{align}
# \gamma \to \frac{\gamma}{\sqrt{E(w^2)}}
# \end{align}
# where $E(w^2)$ is the second moment of the distribution form which the edges are drawn.

# %%
import matplotlib.pyplot as plt
import numpy as np

from qaoa_training_pipeline.utils.graph_utils import load_graph, graph_to_operator
from qaoa_training_pipeline.training import DepthOneScanTrainer, ReweightingTrainer, ScipyTrainer
from qaoa_training_pipeline.evaluation import EfficientDepthOneEvaluator, MPSEvaluator
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
graph = load_graph("../data/problems/example_weighted_graph.json")
cost_op = graph_to_operator(graph)

# %% [markdown]
# Here, we estimate the second moment of the edge weight distribution as the standard deviation. The scaling factor for $\gamma$ is thus its square root.

# %%
scale_factor = np.sqrt(np.std([edge[2]["weight"] ** 2 for edge in graph.edges(data=True)]))
print(f"Gamma rescaling factor {scale_factor:.2f}")
# Out:
# Gamma rescaling factor 4.23

# %% [markdown]
# ## Depth-one QAOA
#
# We compare parameter finding with three methods:
#
# 1. A grid-scan which requires a very fine mesh.
# 2. A SciPy optimization starting from a random initial point.
# 3. The method of Sureshbabu *et al.* in which we first optimize $(\beta, \gamma)$ for the unweighted graph and then use the rescaled optimal point for the weighted graph.

# %%
# Efficient depth-one scan trainer.
trainer1 = DepthOneScanTrainer(
    evaluator=EfficientDepthOneEvaluator(),
    num_points=80,
    parameter_ranges=[(0, np.pi / 2), (0, np.pi / 2)],
)

# SciPy trainer to start from a random initial point.
trainer2 = ScipyTrainer(EfficientDepthOneEvaluator(), {"options": {"maxiter": 40, "rhobeg": 0.2}})

# Re-weighting trainer.
unweighted_trainer = DepthOneScanTrainer(
    evaluator=EfficientDepthOneEvaluator(),
    num_points=40,
    parameter_ranges=[(0, np.pi / 2), (0, np.pi / 4)],
)
reweighted_trainer = ScipyTrainer(
    EfficientDepthOneEvaluator(), {"options": {"maxiter": 40, "rhobeg": 0.1}}
)
trainer3 = ReweightingTrainer(unweighted_trainer, reweighted_trainer)

# %%
result1 = trainer1.provide_params(
    cost_op,
)
print(result1)
# Out:
# ParamResult(data={'system_info': {'python_version': '3.10.20', 'system': 'Darwin', 'processor': 'arm', 'platform': 'macOS-26.5.2-arm64-arm-64bit', 'qaoa_training_pipeline_version': 41}, 'optimized_params': [0.39766995615060674, 0.05965049342259102], 'optimized_qaoa_angles': [0.39766995615060674, 0.05965049342259102], 'train_duration': 4.042587995529175, 'energy': 18.26582449168054, 'trainer': {'trainer_name': 'DepthOneScanTrainer', 'evaluator': {'name': 'EfficientDepthOneEvaluator'}, 'qaoa_angles_function': {'function_name': 'IdentityFunction'}}, 'num_points': 80, 'parameter_ranges': [(0, 1.5707963267948966), (0, 1.5707963267948966)], 'energy_history': [0.0, 2.220446049250313e-16, 4.718447854656915e-16, 1.6653345369377348e-16, -5.551115123125783e-17, -1.6653345369377348e-16, -1.3877787807814457e-15, -2.7755575615628914e-16, -2.7755575615628914e-17, 0.0, -1.6653345369377348e-16, 5.551115123125783e-17, 1.3877787807814457e-16, 9.992007221626409e-16, -1.6653345369377348e-16, -1.942890293094024e-16, 3.3306690738754696e-16, -2.220446049250313e-16, -2.7755575615628914e-16, -4.996003610813204e-16, 0.0, -3.885780586188048e-16, -5.551115123125783e-16, 6.38378239159465e-16, 3.0531133177191805e-16, 5.273559366969494e-16, -2.7755575615628914e-16, 1.6653345369377348e-16, 5.551115123125783e-17, 8.881784197001252e-16, 3.885780586188048e-16, 3.885780586188048e-16, 0.0, 4.996003610813204e-16, 1.6653345369377348e-16, -2.7755575615628914e-16, 3.885780586188048e-16, 1.3877787807814457e-15, 7.771561172376096e-16, -3.3306690738754696e-16, -4.996003610813204e-16, 0.0, 1.6653345369377348e-16, 2.220446049250313e-16, 3.3306690738754696e-16, -8.604228440844963e-16, -3.3306690738754696e-16, 7.216449660063518e-16, 6.661338147750939e-16, 6.661338147750939e-16, 2.7755575615628914e-16, 6.106226635438361e-16, -8.604228440844963e-16, -2.7755575615628914e-16, -3.885780586188048e-16, 1.3877787807814457e-15, -5.828670879282072e-16, 4.718447854656915e-16, 5.551115123125783e-16, 8.326672684688674e-17, -3.885780586188048e-16, 1.942890293094024e-16, 0.0, 5.551115123125783e-17, 5.551115123125783e-16, -2.220446049250313e-16, -2.7755575615628914e-16, -5.551115123125783e-17, 3.0531133177191805e-16, 4.996003610813204e-16, -5.551115123125783e-17, -1.1102230246251565e-16, -4.718447854656915e-16, -9.43689570931383e-16, -6.106226635438361e-16, -4.440892098500626e-16, -3.885780586188048e-16, 0.0, -2.220446049250313e-16, 0.0, 0.0, 0.6704201121332293, 1.1666525064499418, 1.3769420436079285, 1.28940683769093, 0.9860194501934011, 0.5995222614247887, 0.25540646163704, 0.026325634374587598, -0.08209254888844644, -0.11219340943947345, -0.116777700126235, -0.12548954794488934, -0.13268108009489368, -0.11051923466767893, -0.03634806940509194, 0.08418708463982472, 0.21317026933836558, 0.2983489434137154, 0.3022235943206541, 0.22457589166647463, 0.10428673527065044, -0.0016641066050677167, -0.05055548060249332, -0.038959864695262636, -0.005255037483290204, -0.006890269963803181, -0.08428927791897817, -0.23173008163124978, -0.392803129906494, -0.48519062495961973, -0.4432965554034582, -0.2565476066585215, 0.017889201823224288, 0.2766949342029337, 0.41721417111578946, 0.38671253464511185, 0.2091026373796318, -0.025047919853461387, -0.20103552874929226, -0.23437511049255222, -0.1102551595462552, 0.11107069461524693, 0.3248772739525865, 0.4325174733515217, 0.3864843960137933, 0.20832740164121905, -0.027567133819170503, -0.2337227469308819, -0.3509942972495312, -0.370557991777541, -0.32718586782898285, -0.2705974171449478, -0.23312717574978986, -0.21269029394435332, -0.18006196488103174, -0.10474081545163305, 0.01738814538349437, 0.1524784971205594, 0.24169797771859464, 0.23265680265518365, 0.11181490917132098, -0.0812148250637311, -0.2672499803501516, -0.36356435906239426, -0.32415248629407883, -0.16291594922239025, 0.05304351119769851, 0.2371227299830933, 0.32651391406925845, 0.3123457599098949, 0.2407386096425191, 0.18432330911586856, 0.19964691888041386, 0.29358871214865984, 0.417203386765 ...

# %%
result2 = trainer2.provide_params(cost_op, params0=np.random.uniform(0, np.pi / 2, 2))
print(result2["optimized_params"])
# Out:
# [1.0958094071307196, 0.5978142217124055]

# %%
result3 = trainer3.provide_params(
    cost_op,
    trainer1_kwargs={},
)
print(result3["optimized_params"])
# Out:
# [0.41457818894329945, 0.06470557512690106]

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
trainer1.plot(axis=axs[0][0], fig=fig)
trainer1.plot(axis=axs[0][1], fig=fig)
assert isinstance(trainer3.unweighted_trainer, DepthOneScanTrainer)
trainer3.unweighted_trainer.plot(axis=axs[1][0], fig=fig)
axs[0][0].scatter(
    result3["optimized_params"][1],
    result3["optimized_params"][0],
    s=60,
    color="g",
    marker="*",
    ec="k",
)
axs[0][0].scatter(
    result2["optimized_params"][1],
    result2["optimized_params"][0],
    s=60,
    color="r",
    marker="*",
    ec="k",
)
assert isinstance(trainer3.weighted_trainer, ScipyTrainer)
trainer3.weighted_trainer.plot(
    axis=axs[1][1], fig=fig, color="forestgreen", label="Re-weighting method"
)
trainer2.plot(axis=axs[1][1], fig=fig, color="firebrick", label="Random initial point")
axs[0][1].set_xlim([0, 0.4])
axs[1][1].legend()
axs[0][0].set_title("Depth-one landscape")
axs[0][1].set_title("Depth-one landscape zoom")
axs[1][0].set_title("Depth-one landscape of unweighted graph")
axs[1][1].set_title("SciPy optimization convergence")
# Out:
# Text(0.5, 1.0, 'SciPy optimization convergence')

# %% [markdown]
# From the figures above we see that the optimization landscape of the weighted problem is very complex with many local minima. This causes a direct optimization with SciPy to get stuck in local optima, see the red star in the top right panel. However, the unweighted problem has a much smoother optimization landscape. Furthermore, we see in the top panels that the global optima of the weighted problem are compressed towards $\gamma=0$. These optima correspond to the optima in the lower left panel located closest to $\gamma=0$. Crucially, we see that, for example, the $\gamma$ values of the optima close to $\gamma=0$ for the unweighted graph can be rescaled to obtain a good initial guess to find the optima of the weighted graph. This gives some visual intuition as to why the rescaling above can produce good initial points.

# %%
print("Optimal gamma value for the unweighted graph: ", result1["optimized_params"][0])
print("Initial guess based on rescaled gamma: ", result1["optimized_params"][0] / scale_factor)
print("Optimal gamma value for the weighted graph: ", result3["optimized_params"][1])
# Out:
# Optimal gamma value for the unweighted graph:  0.39766995615060674
# Initial guess based on rescaled gamma:  0.0940069396447286
# Optimal gamma value for the weighted graph:  0.06470557512690106

# %% [markdown]
# ## Depth-two QAOA
#
# We now repeat the same procedure for depth-two QAOA.

# %%
# SciPy trainer to start from a random initial point.
trainer4 = ScipyTrainer(
    MPSEvaluator(threshold_circuit=0.001), {"options": {"maxiter": 40, "rhobeg": 0.2}}
)

# Re-weighting trainer.
unweighted_trainer = ScipyTrainer(
    MPSEvaluator(threshold_circuit=0.001), {"options": {"maxiter": 40, "rhobeg": 0.2}}
)
reweighted_trainer = ScipyTrainer(
    MPSEvaluator(threshold_circuit=0.001), {"options": {"maxiter": 40, "rhobeg": 0.1}}
)
trainer5 = ReweightingTrainer(unweighted_trainer, reweighted_trainer)

# %%
params0 = np.random.uniform(0, np.pi, 4)
result4 = trainer4.provide_params(cost_op, params0=params0)
print(result4["optimized_params"])
# Out:
# [0.6085182480805896, 1.8053594952780834, 2.6770122646145995, 1.3460240830219528]

# %%
result5 = trainer5.provide_params(cost_op, trainer1_kwargs={"params0": params0})
print(result5["optimized_params"])
# Out:
# [0.9536241161516067, 1.9634706894185208, 0.5981013582948677, 0.3046751964110671]

# %%
fig, axs = plt.subplots(1, 1, figsize=(10, 5))
trainer4.plot(axis=axs, fig=fig, ls="--", label="Direct training on the weighted graph")
assert isinstance(trainer5.unweighted_trainer, ScipyTrainer)
trainer5.unweighted_trainer.plot(
    axis=axs, fig=fig, color="dodgerblue", label="Un-weighted training"
)
assert isinstance(trainer5.weighted_trainer, ScipyTrainer)
trainer5.weighted_trainer.plot(axis=axs, fig=fig, color="forestgreen", label="Weighted training")
axs.legend()

# %% [markdown]
# Note: the results above differ very significantly depending on the initial point `params0`. Depending on the initial point and optimizer settings, a direct optimization on the weighted graph can outperform the unweighting and re-weighting methodology. In the example above, applying a standard SciPy trainer directly to the weighted graph using a random initial point $x_0$ results in the dashed blue line above. We can obtain a better energy if we instead (i) start the training from the same $x_0$ but on an unweighted graph first to generate a new initial point $x_0'$. Next, (ii) this $x_0'$ is used as the initial point for the training on the weighted graph with SciPy. This two-step process is shown by the solid lines in the plot above. We can see that the solid green line reaches a higher energy than the dashed blue line.
